# %%
import pandas as pd
from openpyxl import load_workbook

# %%
data = pd.read_excel('../data/match_data_1.xlsx')
data['match'] = 1
data['rally'].fillna(method='ffill', inplace=True)
data['rally'] = data['rally'].astype(int)
data.head(10)
# Out:
#    match  rally  ball_round  roundscore_player  roundscore_opponent player  \
# 0      1      1           1                  0                    0      B
# 1      1      1           2                  0                    0      A
# 2      1      1           3                  0                    0      B
# 3      1      2           1                  1                    0      A
# 4      1      2           2                  0                    1      B
# 5      1      2           3                  1                    0      A
# 6      1      2           4                  0                    1      B
# 7      1      2           5                  1                    0      A
# 8      1      2           6                  0                    1      B
# 9      1      2           7                  1                    0      A
#
#    server  ball_location_x  ball_location_y  ball_height  ...      time  \
# ...

# %%
data.to_csv('../data/preprocessed_pass_1.csv', index=False)
